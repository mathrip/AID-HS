# %% [markdown]
# # Notebook to analyse the demographic and clinical information from the cohort
#
# This notebook is used to create Table 1 of the manuscript

# %%
import os
import numpy as np
import pandas as pd
from aidhs.paths import BASE_PATH
# Out:
# Setting BASE_PATH to /home/mathilde/Documents/projects/surHippo/processes/230315_preprocess_manuscript

# %% [markdown]
# Load the dataset with subjects to include and the demographic file

# %%
# get list of subjects
dataset_file = os.path.join(BASE_PATH,'dataset_C-P-DC_alltrain.csv')
df_dataset = pd.read_csv(dataset_file)

subjects = df_dataset['subject_id'].values
print(len(subjects))
# Out:
# 363

# %%
#get demographic information
csv_file = os.path.join(BASE_PATH,'demographics_qc_allgroups.csv')
df_demos = pd.read_csv(csv_file)
df_demos.head()
# Out:
#        ID                                   Freesurfer_folder Freesurfer_ids  \
# 0  H1C0001  /home/mathilde/Documents/projects/surHippo/pro...        sub-017
# 1  H1C0002  /home/mathilde/Documents/projects/surHippo/pro...        sub-018
# 2  H1C0003  /home/mathilde/Documents/projects/surHippo/pro...        sub-019
# 3  H1C0004  /home/mathilde/Documents/projects/surHippo/pro...        sub-020
# 4  H1C0005  /home/mathilde/Documents/projects/surHippo/pro...        sub-021
#
#                                          bids_folder bids_ids  \
# 0  /home/mathilde/Documents/projects/surHippo/pro...  H1C0001
# 1  /home/mathilde/Documents/projects/surHippo/pro...  H1C0002
# 2  /home/mathilde/Documents/projects/surHippo/pro...  H1C0003
# 3  /home/mathilde/Documents/projects/surHippo/pro...  H1C0004
# 4  /home/mathilde/Documents/projects/surHippo/pro...  H1C0005
#
#                                    Hippunfold_folder Hippunfold_ids Site  \
# 0  /home/mathilde/Documents/projects/surHippo/pro...        H1C0001   H1
# 1  /home/mathilde/Documents/projects/surHippo/pro...        H1C0002   H1
# 2  /home/mathilde/Documents/projects/surHippo/pro...        H1C0003   H1
# 3  /home/mathilde/Documents/projects/surHippo/pro...        H1C0004   H1
# 4  /home/mathilde/Documents/projects/surHippo/pro...        H1C0005   H1
#
#   Scanner  Patient or Control (Patient = 1, Control = 0)  ...  \
# 0      3T                                              0  ...
# 1      3T                                              0  ...
# 2      3T                                              0  ...
# 3      3T                                              0  ...
# 4      3T                                              0  ...
#
#   Surgery (Y=1,N=0, control= 666)  Unnamed: 23  \
# 0                             NaN          NaN
# 1                             NaN          NaN
# 2                             NaN          NaN
# 3                             NaN          NaN
# 4                             NaN          NaN
#
#    If other - please provide details.1  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   Engel Outcome (I=1, II=2, III=3, IV=4, NO=not operated, operated but data not available = 555, control= 666)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   f/u for Engel (yr) (NO = not operated, missing data = 555, control= 666)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Lesion Mask (Y=1, N=0,  control= 666)  3D FLAIR (1=yes, 0=no)  \
# 0                                   NaN                     NaN
# 1                                   NaN                     NaN
# 2                                   NaN                     NaN
# 3                                   NaN                     NaN
# 4                                   NaN                     NaN
#
#    QC (good=1, borderline=2, poor=3) Notes  Freesurfer version (5.3 or 6.0)
# 0                                NaN   NaN                              NaN
# 1                                NaN   NaN                              NaN
# 2                                NaN   NaN                              NaN
# 3                                NaN   NaN                              NaN
# 4                                NaN   NaN                              NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# Create a dataframe with the demographic information for each subject of the dataset

# %%
df=pd.DataFrame()
for subject in subjects : 
    # print(subject)
    row=df_demos[df_demos['ID ']==subject]
    values={}
    values['ID']=subject
    values['site']=row["Site"].values[0]
    values['group'] = row["group"].values[0]
    values['lesional_hemi'] = row["Lesional hemi"].values[0]
    values['age_scan'] = row["Age at preoperative"].values[0]
    values['sex'] = row["Sex"].values[0]
    values['mri_neg'] = row["Ever reported MRI negative (yes=1, no=0, control=666)"].values[0]
    values['age_onset'] = row["Age of onset of epilepsy (yr)  (control= 666)"].values[0]
    values['lobes'] = row["Lobes"].values[0]
    df2 = pd.DataFrame([values])
    df = pd.concat([df, df2], ignore_index=True)

# %%
df
# Out:
#                ID site group lesional_hemi  age_scan  sex  mri_neg  age_onset  \
# 0        H11P0001  H11     P            rh      31.0  1.0      0.0        3.0
# 1        H11P0002  H11     P            lh      12.0  1.0      1.0        7.0
# 2        H11P0003  H11     P            lh      11.0  1.0      1.0        8.0
# 3        H11P0004  H11     P            lh      30.0  1.0      0.0       25.0
# 4        H11P0005  H11     P            lh      30.0  1.0      0.0       28.0
# ..            ...  ...   ...           ...       ...  ...      ...        ...
# 358  AIDHSH29C0026  H29     C           NaN      31.0  0.0      NaN        NaN
# 359  AIDHSH29C0027  H29     C           NaN      64.0  1.0      NaN        NaN
# 360  AIDHSH29C0028  H29     C           NaN      41.0  1.0      NaN        NaN
# 361  AIDHSH29C0029  H29     C           NaN      23.0  1.0      NaN        NaN
# 362  AIDHSH29C0030  H29     C           NaN      26.0  1.0      NaN        NaN
#
#     lobes
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 358   NaN
# 359   NaN
# 360   NaN
# 361   NaN
# 362   NaN
#
# [363 rows x 9 columns]

# %% [markdown]
# ### Analyse cohort

# %% [markdown]
# Analyse per group

# %%
df.groupby(['group']).count()
# Out:
#         ID  site  lesional_hemi  age_scan  sex  mri_neg  age_onset  lobes
# group
# C      121   121              0       121  121        0          0      0
# DC      90    90             27        90   90       57         33     60
# P      152   152            152       152  152      152        147     80

# %%
df.groupby(['site','group'])['ID'].count()
# Out:
# site  group
# H1    C        91
#       DC       27
#       P        22
# H11   DC       33
#       P        72
# H16   DC       30
#       P        13
# H29   C        30
#       P        45
# Name: ID, dtype: int64

# %% [markdown]
# Analyse the sex [ 0 male : 1 female]

# %%
df.groupby(['site', 'group', 'sex'])['ID'].count()
# Out:
# site  group  sex
# H1    C      0.0    26
#              1.0    65
#       DC     0.0    12
#              1.0    15
#       P      0.0    13
#              1.0     9
# H11   DC     0.0    19
#              1.0    14
#       P      0.0    41
#              1.0    31
# H16   DC     0.0    15
#              1.0    15
#       P      0.0     6
#              1.0     7
# H29   C      0.0    12
#              1.0    18
#       P      0.0    17
#              1.0    28
# Name: ID, dtype: int64

# %%
df.groupby(['group', 'sex'])['ID'].count()
# Out:
# group  sex
# C      0.0    38
#        1.0    83
# DC     0.0    46
#        1.0    44
# P      0.0    77
#        1.0    75
# Name: ID, dtype: int64

# %%
# chi square stats on sex
from scipy.stats import chisquare

m = np.array([[38,46,77],[83,44,75]])   # C - DC - P , M - F

count_group = m.sum(axis=0)   
count_sex = m.sum(axis=1)
tot = m.sum()


Emc  =  (count_group[0]*count_sex[0])/tot
Emdc =  (count_group[1]*count_sex[0])/tot
Emp  =  (count_group[2]*count_sex[0])/tot

Efc  =  (count_group[0]*count_sex[1])/tot
Efdc =  (count_group[1]*count_sex[1])/tot
Efp  =  (count_group[2]*count_sex[1])/tot

f_obs = m.flatten()
f_exp = np.array([Emc, Emdc, Emp, Efc, Efdc, Efp])

chisquare(f_obs=f_obs, f_exp=f_exp)
# Out:
# Power_divergenceResult(statistic=12.332774777559488, pvalue=0.030501819358745862)

# %% [markdown]
# Analyse per age

# %%
df.groupby(['site','group'])['age_scan'].quantile([0.25,0.5,0.75])
# Out:
# site  group
# H1    C      0.25    10.037645
#              0.50    13.460000
#              0.75    16.546708
#       DC     0.25     5.750000
#              0.50     7.200000
#              0.75    11.050000
#       P      0.25     6.400000
#              0.50    12.450000
#              0.75    16.800000
# H11   DC     0.25     9.000000
#              0.50    15.000000
#              0.75    23.000000
#       P      0.25    19.000000
#              0.50    25.500000
#              0.75    30.000000
# H16   DC     0.25    15.872500
#              0.50    22.835000
#              0.75    37.335000
#       P      0.25    21.460000
#              0.50    37.110000
#              0.75    59.300000
# H29   C      0.25    25.250000
#              0.50    37.000000
#              0.75    48.500000
#       P      0.25    31.000000
#              0.50    41.000000
#              0.75    46.000000
# Name: age_scan, dtype: float64

# %%
df.groupby(['site','group'])['age_scan'].max()
# Out:
# site  group
# H1    C        59.52
#       DC       16.70
#       P        18.50
# H11   DC       48.00
#       P        39.00
# H16   DC       59.08
#       P        69.02
# H29   C        64.00
#       P        56.00
# Name: age_scan, dtype: float64

# %%
df.groupby(['group'])['age_scan'].quantile([0.25,0.5,0.75])
# Out:
# group
# C      0.25    11.947981
#        0.50    15.200548
#        0.75    24.000000
# DC     0.25     7.200000
#        0.50    14.300000
#        0.75    23.000000
# P      0.25    18.225000
#        0.50    27.000000
#        0.75    38.000000
# Name: age_scan, dtype: float64

# %%
import matplotlib.pyplot as plt
age_controls = df[df['group']=='C']['age_scan'].values

plt.hist(age_controls, bins=20)
plt.xlabel('age')
plt.ylabel('number')
# Out:
# Text(0, 0.5, 'number')

# %%
#categorise between children and adults

df['adult_child']=['child' if x<18 else 'adult' for x in df['age_scan']]
df.groupby(['adult_child'])['ID'].count()
# Out:
# adult_child
# adult    200
# child    163
# Name: ID, dtype: int64

# %% [markdown]
# Analyse mri status (0 MRI negative , 1 MRI positive)

# %%
df.groupby(['site', 'group', 'mri_neg'])['ID'].count()
# Out:
# site  group  mri_neg
# H1    DC     0.0        23
#              1.0         4
#       P      0.0        18
#              1.0         4
# H11   P      0.0        53
#              1.0        19
# H16   DC     0.0        29
#              1.0         1
#       P      0.0        12
#              1.0         1
# H29   P      0.0        45
# Name: ID, dtype: int64

# %%
df.groupby(['site', 'group'])['age_onset'].quantile([0.25,0.5,0.75])
# Out:
# site  group
# H1    C      0.25      NaN
#              0.50      NaN
#              0.75      NaN
#       DC     0.25      NaN
#              0.50      NaN
#              0.75      NaN
#       P      0.25     1.00
#              0.50     2.50
#              0.75     6.00
# H11   DC     0.25     4.00
#              0.50     6.00
#              0.75     8.00
#       P      0.25     5.75
#              0.50    11.00
#              0.75    15.25
# H16   DC     0.25      NaN
#              0.50      NaN
#              0.75      NaN
#       P      0.25     9.00
#              0.50    11.00
#              0.75    29.00
# H29   C      0.25      NaN
#              0.50      NaN
#              0.75      NaN
#       P      0.25     3.00
#              0.50    11.00
#              0.75    17.00
# Name: age_onset, dtype: float64

# %%
df.groupby(['group'])['age_onset'].quantile([0.25,0.5,0.75])
# Out:
# group
# C      0.25     NaN
#        0.50     NaN
#        0.75     NaN
# DC     0.25     4.0
#        0.50     6.0
#        0.75     8.0
# P      0.25     3.5
#        0.50     9.0
#        0.75    16.0
# Name: age_onset, dtype: float64

# %%
## lobes in FCD


df.groupby(['group','lobes'])['ID'].count()
# Out:
# group  lobes
# DC     frontal                        38
#        frontal+insular                 2
#        insular                         2
#        occipital                       1
#        parietal                        8
#        temporal                        7
#        temporal+frontal                1
#        temporal+parietal+occipital     1
# P      hemispherotomy                  2
#        temporal                       77
#        temporal+parietal+occipital     1
# Name: ID, dtype: int64
